# %%
import cv2
import matplotlib.pyplot as plt

# 動画の開始フレーム
frameIndex = 9005

# 動画読み込み
cap = cv2.VideoCapture("puyo_video.mp4")
cap.set(cv2.CAP_PROP_POS_FRAMES, frameIndex)
ref, frame = cap.read()
img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

# トリミング
field = img[30 : 335, 90: 250]

row_1 = field[255 : 276, 8: 150]
row_2 = field[233 : 254, 8: 150]
row_3 = field[211 : 232, 8: 150]
row_4 = field[188 : 210, 8: 150]
row_5 = field[165 : 187, 8: 150]
row_6 = field[142 : 164, 8: 150]
row_7 = field[119 : 141, 8: 150]

field_1_1 = row_1[0 : 22, 0 : 24]
field_1_2 = row_1[0 : 22, 24 : 48]
field_1_3 = row_1[0 : 22, 48 : 72]
field_1_4 = row_1[0 : 22, 72 : 96]
field_1_5 = row_1[0 : 22, 96 : 120]
field_1_6 = row_1[0 : 22, 120 : 144]

field_2_1 = row_2[0 : 22, 0 : 24]
field_2_2 = row_2[0 : 22, 24 : 48]
field_2_3 = row_2[0 : 22, 48 : 72]
field_2_4 = row_2[0 : 22, 72 : 96]
field_2_5 = row_2[0 : 22, 96 : 120]
field_2_6 = row_2[0 : 22, 120 : 144]

field_3_1 = row_3[0 : 22, 0 : 24]
field_3_2 = row_3[0 : 22, 24 : 48]
field_3_3 = row_3[0 : 22, 48 : 72]
field_3_4 = row_3[0 : 22, 72 : 96]
field_3_5 = row_3[0 : 22, 96 : 120]
field_3_6 = row_3[0 : 22, 120 : 144]


field_4_1 = row_4[0 : 22, 0 : 24]
field_4_2 = row_4[0 : 22, 24 : 48]
field_4_3 = row_4[0 : 22, 48 : 72]
field_4_4 = row_4[0 : 22, 72 : 96]
field_4_5 = row_4[0 : 22, 96 : 120]
field_4_6 = row_4[0 : 22, 120 : 144]

field_5_1 = row_5[0 : 22, 0 : 24]
field_5_2 = row_5[0 : 22, 24 : 48]
field_5_3 = row_5[0 : 22, 48 : 72]
field_5_4 = row_5[0 : 22, 72 : 96]
field_5_5 = row_5[0 : 22, 96 : 120]
field_5_6 = row_5[0 : 22, 120 : 144]

field_6_1 = row_6[0 : 22, 0 : 24]
field_6_2 = row_6[0 : 22, 24 : 48]
field_6_3 = row_6[0 : 22, 48 : 72]
field_6_4 = row_6[0 : 22, 72 : 96]
field_6_5 = row_6[0 : 22, 96 : 120]
field_6_6 = row_6[0 : 22, 120 : 144]

field_7_1 = row_7[0 : 22, 0 : 24]
field_7_2 = row_7[0 : 22, 24 : 48]
field_7_3 = row_7[0 : 22, 48 : 72]
field_7_4 = row_7[0 : 22, 72 : 96]
field_7_5 = row_7[0 : 22, 96 : 120]
field_7_6 = row_7[0 : 22, 120 : 144]

fig = plt.figure()
plt.subplot(20, 2, 1),plt.imshow(row_6)
plt.title('6')
plt.subplot(20, 2, 3),plt.imshow(row_5)
plt.title('5')
plt.subplot(20, 2, 5),plt.imshow(row_4)
plt.title('4')
plt.subplot(20, 2, 7),plt.imshow(row_3)
plt.title('3')
plt.subplot(20, 2, 9),plt.imshow(row_2)
plt.title('2')
plt.subplot(20, 2, 11),plt.imshow(row_1)
plt.title('1')

puyo_green = field_1_4
puyo_red = field_2_4
puyo_yellow = field_7_5
puyo_parerpul = field_5_6

plt.subplot(20, 2, 13),plt.imshow(puyo_green)
plt.title('g')
plt.subplot(20, 2, 15),plt.imshow(puyo_red)
plt.title('r')
plt.subplot(20, 2, 17),plt.imshow(puyo_yellow)
plt.title('y')
plt.subplot(20, 2, 19),plt.imshow(puyo_parerpul)
plt.title('p')
# Out:
# Text(0.5, 1.0, 'p')

# %%
# 画像認識サンプル
import cv2
import numpy as np
from IPython.display import Image, display
from matplotlib import pyplot as plt


# 動画の開始フレーム
frameIndex = 9005

# 動画読み込み
cap = cv2.VideoCapture("puyo_video.mp4")
cap.set(cv2.CAP_PROP_POS_FRAMES, frameIndex)
ref, frame = cap.read()
img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

# トリミング
field = img[30 : 335, 90: 250]
row_1 = field[255 : 276, 8: 150]
field_1_1 = row_1[0 : 21, 0 : 24]
field_1_2 = row_1[0 : 21, 24 : 48]
field_1_3 = row_1[0 : 21, 48 : 72]
field_1_4 = row_1[0 : 21, 72 : 96]
field_1_5 = row_1[0 : 21, 96 : 120]
field_1_6 = row_1[0 : 21, 120 : 144]
field_1_6 = row_1[0 : 21, 120 : 144]

# 入力画像、テンプレート画像を読み込む。
img = field # 入力画像
templ = field_1_3

# テンプレートマッチングを行う。
result = cv2.matchTemplate(img, templ, cv2.TM_CCOEFF_NORMED)

# 類似度ヒートマップ(黄色所が類似度が高い)
fig, ax = plt.subplots(figsize=(10, 5))
im = ax.imshow(result, cmap="jet")
fig.colorbar(im)

plt.show()

# 最も類似度が 0.9 以上の位置を取得する。
ys, xs = np.where(result >= 0.9)



params = [
    "TM_SQDIFF",
    "TM_SQDIFF_NORMED",
    "TM_CCORR",
    "TM_CCORR_NORMED",
    "TM_CCOEFF",
    "TM_CCOEFF_NORMED",
]
fig = plt.figure(figsize=(10, 10))
# 描画する。
dst = img.copy()
# plt.imshow(dst)
for x, y in zip(xs, ys):
    cv2.rectangle(
        dst,
        (x, y),
        (x + templ.shape[1], y + templ.shape[0]),
        color=(0, 255, 0),
        thickness=2,
    )
plt.imshow(dst)

# %%
# 画像認識サンプル2
import cv2
import numpy as np
from IPython.display import Image, display
from matplotlib import pyplot as plt


# 動画の開始フレーム
frameIndex = 9505

# 動画読み込み
cap = cv2.VideoCapture("puyo_video.mp4")
cap.set(cv2.CAP_PROP_POS_FRAMES, frameIndex)
ref, frame = cap.read()
img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

# トリミング
field = img[30 : 335, 90: 250]

row_1 = field[255 : 276, 8: 150]
row_2 = field[233 : 254, 8: 150]
row_3 = field[211 : 232, 8: 150]
row_4 = field[188 : 210, 8: 150]
row_5 = field[165 : 187, 8: 150]
row_6 = field[142 : 164, 8: 150]
row_7 = field[119 : 141, 8: 150]

field_1_1 = row_1[0 : 22, 0 : 24]
field_1_2 = row_1[0 : 22, 24 : 48]
field_1_3 = row_1[0 : 22, 48 : 72]
field_1_4 = row_1[0 : 22, 72 : 96]
field_1_5 = row_1[0 : 22, 96 : 120]
field_1_6 = row_1[0 : 22, 120 : 144]

field_2_1 = row_2[0 : 22, 0 : 24]
field_2_2 = row_2[0 : 22, 24 : 48]
field_2_3 = row_2[0 : 22, 48 : 72]
field_2_4 = row_2[0 : 22, 72 : 96]
field_2_5 = row_2[0 : 22, 96 : 120]
field_2_6 = row_2[0 : 22, 120 : 144]

field_3_1 = row_3[0 : 22, 0 : 24]
field_3_2 = row_3[0 : 22, 24 : 48]
field_3_3 = row_3[0 : 22, 48 : 72]
field_3_4 = row_3[0 : 22, 72 : 96]
field_3_5 = row_3[0 : 22, 96 : 120]
field_3_6 = row_3[0 : 22, 120 : 144]


field_4_1 = row_4[0 : 22, 0 : 24]
field_4_2 = row_4[0 : 22, 24 : 48]
field_4_3 = row_4[0 : 22, 48 : 72]
field_4_4 = row_4[0 : 22, 72 : 96]
field_4_5 = row_4[0 : 22, 96 : 120]
field_4_6 = row_4[0 : 22, 120 : 144]

field_5_1 = row_5[0 : 22, 0 : 24]
field_5_2 = row_5[0 : 22, 24 : 48]
field_5_3 = row_5[0 : 22, 48 : 72]
field_5_4 = row_5[0 : 22, 72 : 96]
field_5_5 = row_5[0 : 22, 96 : 120]
field_5_6 = row_5[0 : 22, 120 : 144]

field_6_1 = row_6[0 : 22, 0 : 24]
field_6_2 = row_6[0 : 22, 24 : 48]
field_6_3 = row_6[0 : 22, 48 : 72]
field_6_4 = row_6[0 : 22, 72 : 96]
field_6_5 = row_6[0 : 22, 96 : 120]
field_6_6 = row_6[0 : 22, 120 : 144]

field_7_1 = row_7[0 : 22, 0 : 24]
field_7_2 = row_7[0 : 22, 24 : 48]
field_7_3 = row_7[0 : 22, 48 : 72]
field_7_4 = row_7[0 : 22, 72 : 96]
field_7_5 = row_7[0 : 22, 96 : 120]
field_7_6 = row_7[0 : 22, 120 : 144]

field_list = [
    [field_1_2, field_1_2, field_1_3, field_1_4, field_1_5, field_1_6],
    [field_2_2, field_2_2, field_2_3, field_2_4, field_2_5, field_2_6],
    [field_3_2, field_3_2, field_3_3, field_3_4, field_3_5, field_3_6],
    [field_4_2, field_4_2, field_4_3, field_4_4, field_4_5, field_4_6],
    [field_5_2, field_5_2, field_5_3, field_5_4, field_5_5, field_5_6],
    [field_6_2, field_6_2, field_6_3, field_6_4, field_6_5, field_6_6],
    [field_7_2, field_7_2, field_7_3, field_7_4, field_7_5, field_7_6],
]

puyo_green = field_1_4
puyo_red = field_2_4
puyo_yellow = field_7_5
puyo_parerpul = field_5_6

puyo_green = cv2.cvtColor(puyo_green, cv2.IMREAD_GRAYSCALE)
puyo_red = cv2.cvtColor(puyo_red, cv2.IMREAD_GRAYSCALE)
puyo_yellow = cv2.cvtColor(puyo_yellow, cv2.IMREAD_GRAYSCALE)
puyo_parerpul = cv2.cvtColor(puyo_parerpul, cv2.IMREAD_GRAYSCALE)

plt.subplot(20, 2, 1),plt.imshow(puyo_green)
plt.title('p1')
plt.subplot(20, 2, 3),plt.imshow(puyo_red)
plt.title('p2')
plt.subplot(20, 2, 5),plt.imshow(puyo_yellow)
plt.title('p3')
plt.subplot(20, 2, 7),plt.imshow(puyo_parerpul)
plt.title('p4')

hist_green = cv2.calcHist([puyo_green], [0], None, [256], [0, 256])
hist_red = cv2.calcHist([puyo_red], [0], None, [256], [0, 256])
hist_ywllow = cv2.calcHist([puyo_yellow], [0], None, [256], [0, 256])
hist_parerpul = cv2.calcHist([puyo_parerpul], [0], None, [256], [0, 256])

for row in reversed(field_list):
    for i in range(6):
        target = cv2.cvtColor(row[i], cv2.IMREAD_GRAYSCALE)
        target_hist = cv2.calcHist([target], [0], None, [256], [0, 256])
        
        method = cv2.HISTCMP_INTERSECT
        rate_green = {'color': 'green', 'rate':cv2.compareHist(target_hist, hist_green, method)}
        rate_red = {'color': 'red', 'rate':cv2.compareHist(target_hist, hist_red, method)}
        rate_yellow = {'color': 'yellow', 'rate':cv2.compareHist(target_hist, hist_ywllow, method)}
        rate_parepul = {'color': 'parepul', 'rate':cv2.compareHist(target_hist, hist_parerpul, method)}

        rate_list = [rate_green, rate_red, rate_yellow, rate_parepul]
        color = max(rate_list, key=lambda x: x['rate'])
        if color['rate'] >= 250:
            print(color['color'], end=' ')
        else:
            print('null', end=' ')
            
        # print(color['color'], end=' ')
        
        # print(color['rate'])
    print('')
fig = plt.figure()




# 入力画像、テンプレート画像を読み込む。
img = field # 入力画像
templ = puyo_red

plt.imshow(img)
# Out:
# null null null green yellow green
# null null null green red parepul
# red red red red red parepul
# yellow yellow red yellow yellow yellow
# red red yellow green red parepul
# green green green red red parepul
# red red red green red red
